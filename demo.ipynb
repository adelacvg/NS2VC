# %% [markdown]
# <a href="https://colab.research.google.com/github/adelacvg/NS2VC/blob/master/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/adelacvg/NS2VC.git
# Out:
# Cloning into 'NS2VC'...
# remote: Enumerating objects: 590, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 590 (delta 96), reused 104 (delta 65), pack-reused 447
# Receiving objects: 100% (590/590), 16.52 MiB | 31.21 MiB/s, done.
# Resolving deltas: 100% (357/357), done.

# %%
# %cd NS2VC
# Out:
# /content/NS2VC

# %% [markdown]
# ## NS2VC

# %% [markdown]
# ###Download model takes about 5 minute

# %%
# !git lfs install
# !git clone https://huggingface.co/adelacvg/NS2VC
# Out:
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'NS2VC'...
# remote: Enumerating objects: 22, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 22 (delta 3), reused 0 (delta 0), pack-reused 11
# Unpacking objects: 100% (22/22), 2.70 KiB | 554.00 KiB/s, done.
# Filtering content: 100% (3/3), 4.93 GiB | 15.35 MiB/s, done.
# Encountered 2 file(s) that may not have been copied correctly on Windows:
# 	model-1000_vc_vocos.pt
# 	model-1000_tts_vocos.pt
#
# See: `git lfs help smudge` for more details.

# %%
# !git checkout master
# Out:
# Already on 'master'
# Your branch is up to date with 'origin/master'.

# %%
# !cp NS2VC/checkpoint_best_legacy_500.pt hubert

# %%
# !pip install vocos accelerate matplotlib librosa unidecode inflect ema_pytorch tensorboard fairseq praat-parselmouth
# Out:
# Collecting vocos
#   Downloading vocos-0.0.3-py3-none-any.whl (23 kB)
# Collecting accelerate
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.0.post2)
# Collecting unidecode
#   Downloading Unidecode-1.3.6-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (6.0.5)
# Collecting ema_pytorch
#   Downloading ema_pytorch-0.2.3-py3-none-any.whl (4.4 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.12.3)
# Collecting fairseq
#   Downloading fairseq-0.12.2.tar.gz (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 86.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting praat-parselmouth
#   Downloading praat_parselmouth-0.4.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 102.1 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from vocos) (2.0.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from vocos) (2.0.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vocos) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vocos) (1.10.1)
# Collecting einops (from vocos)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from vocos) (6.0.1)
# Collecting huggingface-hub (from vocos)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.2 MB/s eta 0:00:00
# Collecting encodec==0.1.1 (from vocos)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 101.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.5)
# Requirement already satisfied: pydantic<2,>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect) (1.10.12)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.41.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq) (1.15.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq) (0.29.36)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq)
#   Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 15.3 MB/s eta 0:00:00
# Collecting omegaconf<2.1 (from fairseq)
#   Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq) (2022.10.31)
# Collecting sacrebleu>=1.4.12 (from fairseq)
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq) (4.65.0)
# Collecting bitarray (from fairseq)
#   Downloading bitarray-2.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.8/283.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 15.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa) (1.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (0.9.0)
# Collecting colorama (from sacrebleu>=1.4.12->fairseq)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq) (4.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq) (2.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->vocos) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->vocos) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->vocos) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->vocos) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->vocos) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->vocos) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->vocos) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->vocos) (2023.6.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->vocos) (1.3.0)
# Building wheels for collected packages: encodec, fairseq, antlr4-python3-runtime
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45759 sha256=ba9c434aa7293603a8a54e79e3e167ecec5e5487d9fd6cc7e90807808c85928b
#   Stored in directory: /root/.cache/pip/wheels/fc/36/cb/81af8b985a5f5e0815312d5e52b41263237af07b977e6bcbf3
#   Building wheel for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-cp310-cp310-linux_x86_64.whl size=11288404 sha256=8eae222ca57b9fc6e541d4f1691e6371127233eabb69ab049bbaca489580ca6d
#   Stored in directory: /root/.cache/pip/wheels/e4/35/55/9c66f65ec7c83fd6fbc2b9502a0ac81b2448a1196159dacc32
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141211 sha256=5305858679e5243c10bfe7885999b8a05d93b060ad08c76160b29c7f0405ebdb
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built encodec fairseq antlr4-python3-runtime
# Installing collected packages: bitarray, antlr4-python3-runtime, unidecode, praat-parselmouth, portalocker, omegaconf, einops, colorama, sacrebleu, hydra-core, huggingface-hub, encodec, vocos, fairseq, ema_pytorch, accelerate
# Successfully installed accelerate-0.21.0 antlr4-python3-runtime-4.8 bitarray-2.8.0 colorama-0.4.6 einops-0.6.1 ema_pytorch-0.2.3 encodec-0.1.1 fairseq-0.12.2 huggingface-hub-0.16.4 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.7.0 praat-parselmouth-0.4.3 sacrebleu-2.3.1 unidecode-1.3.6 vocos-0.0.3

# %%
# !mkdir raw
# !mkdir output
# !cp dataset/1/1.wav raw
# !cp dataset/2/2.wav raw

# %%
import IPython
IPython.display.Audio("raw/1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio("raw/2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python infer.py --clean_names="2.wav" --refer_names="1.wav" --model_path=NS2VC/model-1000_vc_vocos.pt --device="cuda"
# Out:
# 2023-08-03 17:08:51.433790: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-03 17:08:53.571753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# load model(s) from hubert/checkpoint_best_legacy_500.pt
# INFO:fairseq.tasks.text_to_speech:Please install tensorboardX: pip install tensorboardX
# INFO:fairseq.tasks.hubert_pretraining:current directory is /content/NS2VC
# INFO:fairseq.tasks.hubert_pretraining:HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# INFO:fairseq.models.hubert.hubert:HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# phoneme params: 69497856
# f0 params: 50540035
# prompt params: 69286600
# diff params:  185027884
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /charactr/vocos-mel-24khz/resolve/main/config.yaml HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 136135931940672 on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/538262138a8b43863802f279909f26ec31c766b3.lock
# DEBUG:filelock:Lock 136135931940672 acquired on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/538262138a8b43863802f279909f26ec31c766b3.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /charactr/vocos-mel-24khz/resolve/main/config.yaml HTTP/1.1" 200 461
# Downloading (…)lve/main/config.yaml: 100% 461/461 [00:00<00:00, 3.11MB/s]
# DEBUG:filelock:Attempting to release lock 136135931940672 on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/538262138a8b43863802f279909f26ec31c766b3.lock
# DEBUG:filelock:Lock 136135931940672 released on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/538262138a8b43863802f279909f26ec31c766b3.lock
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /charactr/vocos-mel-24khz/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 136138385596544 on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/86058aa396f186e295ff06645b41bbeb04cf2183a0f6735a035bd7fbd1528c75.lock
# DEBUG:filelock:Lock 136138385596544 acquired on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/86058aa396f186e295ff06645b41bbeb04cf2183a0f6735a035bd7fbd1528c75.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /repos/ff/79/ff7998b5eb792afbb5deb23adb6ae6fcdacce821d90115c14744a57f34ece077/86058aa396f186e295ff06645b41bbeb04cf2183a0f6735a035bd7fbd1528c75?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27pytorch_model.bin%3B+filename%3D%22pytorch_model.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1691341786&Policy=~cmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=w-khF2MI8Y6GWNeV-4Khg8fZDLlc3UEs4y-oJd0MDHcFJRc4bHDTyyAoOzx-ZaK3P-04fwlfhzUl6qSFniGyWrYQX3civbRwEjA6XwGvt3jrFIGqy-JrJtOW7zk-2NMZzUCTc6WiSOvT-05fc5GSu3KGYQ8pc9rWLZ5OYYS-xZJNMIq7nQwF7y8XpUZV7UMNzSw0VC5dLRgSIPzWa0XxtbUfH7WSzPbfAsFkVh-1RCLXg7hi7E6U8PlaGrZh0yCpUTUZPYPB8LUh~i6Flk6EmN4rhlIdk46--eiowbt7r6WUtJB6LC3~7fkcQjgCej-us4LpQAMqYYaV33k1CYL~ng__&Key-Pair-Id=KVTP0A1DKRTAX HTTP/1.1" 200 54368426
# Downloading pytorch_model.bin: 100% 54.4M/54.4M [00:00<00:00, 171MB/s]
# DEBUG:filelock:Attempting to release lock 136138385596544 on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/86058aa396f186e295ff06645b41bbeb04cf2183a0f6735a035bd7fbd1528c75.lock
# DEBUG:filelock:Lock 136138385596544 released on /root/.cache/huggingface/hub/models--charactr--vocos-mel-24khz/blobs/86058aa396f186e295ff06645b41bbeb04cf2183a0f6735a035bd7fbd1528c75.lock
# #=====segment start, 1.109s======
# sampling loop time step: 100% 200/200 [00:08<00:00, 23.17it/s]
# ns2vc use time:8.815053224563599

# %%
IPython.display.Audio("output/2.wav_auto_1.wav.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##TTS

# %%
# !git checkout tts
# Out:
# Branch 'tts' set up to track remote branch 'tts' from 'origin'.
# Switched to a new branch 'tts'

# %%
# !pip install g2p_en unidecode pypinyin
# Out:
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.6)
# Collecting pypinyin
#   Downloading pypinyin-0.49.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (1.22.4)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (3.8.1)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (6.0.5)
# Collecting distance>=0.1.3 (from g2p_en)
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydantic<2,>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=0.3.1->g2p_en) (1.10.12)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1.9.1->inflect>=0.3.1->g2p_en) (4.7.1)
# Building wheels for collected packages: distance
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16257 sha256=b2ff9185f59327517d194c1c9fd45f979985dcb5a781de5bdfed1c09a2909018
#   Stored in directory: /root/.cache/pip/wheels/e8/bb/de/f71bf63559ea9a921059a5405806f7ff6ed612a9231c4a9309
# Successfully built distance
# Installing collected packages: distance, pypinyin, g2p_en
# Successfully installed distance-0.1.3 g2p_en-2.1.0 pypinyin-0.49.0

# %%
# !python tts_infer.py --text="Hello world." --refer="2.wav" --model_path=NS2VC/model-1000_tts_vocos.pt --device="cuda"
# Out:
# INFO:torch.distributed.nn.jit.instantiator:Created a temporary directory at /tmp/tmphps7jn6q
# INFO:torch.distributed.nn.jit.instantiator:Writing /tmp/tmphps7jn6q/_remote_module_non_scriptable.py
# 2023-08-03 17:10:52.853090: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-08-03 17:10:53.843501: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.10/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.xla_bridge:No jax_plugins namespace packages available
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# phoneme params: 69426176
# f0 params: 51194881
# duration params: 34941953
# prompt params: 69286600
# time_mlp params: 2099712
# out_proj params: 52324
# residual_layers params: 157593600
# cross_attn params: 13631488
# film params: 6842368
# prompt_proj params: 3427840
# diff params:  185027884
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /charactr/vocos-mel-24khz/resolve/main/config.yaml HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /charactr/vocos-mel-24khz/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# Raw Text Sequence: Hello world
# Phoneme Sequence: {HH AH0 L OW1 W ER1 L D}
# sampling loop time step: 100% 200/200 [00:10<00:00, 19.78it/s]

# %%
IPython.display.Audio("output/tts_2.wav.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
