# %% [markdown]
# <a href="https://colab.research.google.com/github/adelacvg/NS2VC/blob/vc-v2/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/adelacvg/NS2VC.git
# Out:
# Cloning into 'NS2VC'...
# remote: Enumerating objects: 763, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 763 (delta 219), reused 286 (delta 175), pack-reused 413
# Receiving objects: 100% (763/763), 16.78 MiB | 7.66 MiB/s, done.
# Resolving deltas: 100% (446/446), done.

# %%
# %cd NS2VC
# Out:
# /content/NS2VC

# %% [markdown]
# ## NS2VC

# %% [markdown]
# ###Download model

# %%
# !git lfs install
# !git clone https://huggingface.co/adelacvg/NS2VC
# Out:
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'NS2VC'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 37 (delta 9), reused 0 (delta 0), pack-reused 11
# Unpacking objects: 100% (37/37), 4.37 KiB | 559.00 KiB/s, done.
# Filtering content: 100% (2/2), 1.61 GiB | 17.98 MiB/s, done.

# %%
# !git checkout vc-v2
# Out:
# Switched to branch 'vc-v2'
# Your branch is up to date with 'origin/vc-v2'.

# %%
# !cp NS2VC/checkpoint_best_legacy_500.pt hubert

# %%
# !pip install vocos accelerate matplotlib librosa unidecode inflect ema_pytorch tensorboard fairseq praat-parselmouth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 73.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 109.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 54.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 16.6 MB/s eta 0:00:00
# ...

# %%
# !mkdir raw
# !mkdir output
# !cp dataset/1/1.wav raw
# !cp dataset/2/2.wav raw

# %%
import IPython
IPython.display.Audio("raw/1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio("raw/2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !python infer.py --clean_names="1.wav" --refer_names="2.wav" --model_path=NS2VC/vc_v2-1000.pt --device="cuda"
# Out:
# 2023-10-03 12:57:49.515698: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2023-10-03 12:57:50.657431: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# ...

# %%
IPython.display.Audio("output/1.wav_auto_2.wav.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Diff VITS

# %%
# %cd ../diff-vits

# %%
# !pip install g2p_en unidecode pypinyin

# %%
# !python tts_infer.py --text="Hello world." --refer="2.wav" --model_path=NS2VC/model-1000_tts_vocos.pt --device="cuda"

# %%
IPython.display.Audio("output/tts_2.wav.wav")
